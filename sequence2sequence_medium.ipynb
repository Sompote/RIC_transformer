# %% [markdown]
# <a href="https://colab.research.google.com/github/Sompote/RIC_transformer/blob/main/sequence2sequence_medium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q --upgrade keras-nlp #install nlp for keras
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 573.5/573.5 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.1/880.1 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 28.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.1/524.1 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 39.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 27.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 17.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pydantic 2.1.1 requires typing-extensions>=4.6.1, but you have typing-extensions 4.5.0 which is incompatible.
# pydantic-core 2.4.0 requires typing-extensions!=4.7.0,>=4.6.0, but you have typing-extensions 4.5.0 which is incompatible.

# %%
# !pip install -q keras-core #option change system

# %%
import os #option change system

os.environ["KERAS_BACKEND"] = "jax"

# Note that keras_core should only be imported after the backend
# has been configured. The backend cannot be changed once the
# package is imported.
import keras_core as keras
# Out:
# Using JAX backend.

# %%
#Transformer Autoencoder to predict RIC combind model by Dr. Sompote Youwai 2023
import numpy as np
import pandas as pd

# Import libraries
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import pandas as pd



df = pd.read_excel('/content/drive/MyDrive/RIC/RIC15aug.xlsx')
data=np.array(df)
X=data[:,1:29]
Y=data[:,34:62]
x_feature=data[:,29:32]

# %%
#scale data
X_train=X
Y_train=Y
sc_y=StandardScaler()
sc = StandardScaler()
sc_f=StandardScaler()
X_feature=x_feature
X_train=X

x_train = sc.fit_transform(X_train)
y_train=sc_y.fit_transform(Y_train)
x_feature=sc_f.fit_transform(X_feature)

# %%
#preparing input matrix
#first dim is time step, 2-4 is feature
X_train_CNN=np.zeros((X.shape[0],X.shape[1],X_feature.shape[1]+1))
X_train_CNN[:,:,0]=x_train
for i in range(0,(X.shape[0])):
  X_train_CNN[i,:,1]=x_feature[i,0]
  X_train_CNN[i,:,2]=x_feature[i,1]
  X_train_CNN[i,:,3]=x_feature[i,2]

# %%
X_train_CNN.shape
# Out:
# (26, 28, 4)

# %%
x_feature.shape
# Out:
# (34, 3)

# %%
#preparing data for training each time step for each Y data using concept seq2seq
def encoder_f(x_f,time_step): #feature encoder same feature in each sample
  shape=x_f.shape
  x=x_f
  step=time_step
  x_sum_t=x[0:1,:]
  for time in range(1,time_step):
    x_sum=x[0:1,:]
    x_sum_t=np.append(x_sum_t,x_sum,axis=0)
  sum_X=x_sum_t

  for sample in range(1,shape[0]):
    x_sum_ts=x[sample:sample+1,:]

    for time in range(1,time_step):
        x_sum=x[sample:sample+1,:]
        #x_sum=np.reshape(x_sum,(1,x_sum.shape[0],x_sum.shape[1]))


        x_sum_ts=np.append(x_sum_ts,x_sum,axis=0)

    sum_X=np.append(sum_X,x_sum_ts,axis=0)
  return sum_X

#prepare x in encoder #enter CNN and use similar encode for  smaple in diffrent time step
def encoder_x(x_cnn):
  shape=x_cnn.shape
  x=x_cnn

  x_sum_t=x[0:1,:,:]
  for time in range(1,shape[1]):
    x_sum=x[0:1,:,:]
    x_sum=np.reshape(x_sum,(1,x_sum.shape[1],x_sum.shape[2]))
    x_sum_t=np.append(x_sum_t,x_sum,axis=0)

  sum_X=x_sum_t

  for sample in range(1,shape[0]):
    x_sum_ts=x[sample:sample+1,:,:]

    for time in range(1,shape[1]):
        x_sum=x[sample,:,:]
        x_sum=np.reshape(x_sum,(1,x_sum.shape[0],x_sum.shape[1]))
        x_sum_ts=np.append(x_sum_ts,x_sum,axis=0)

    sum_X=np.append(sum_X,x_sum_ts,axis=0)
  return sum_X

def padding(x_pad,shift=1): #padding time shift right -shift right =1
  xt=x_pad
  if (shift>0):
    ap=np.zeros((xt.shape[0],shift))
    xt=np.concatenate((ap,xt), axis=1)
  xt_1 = xt[0,0:1]
  xt_p1=  np.pad(xt_1, (0, xt.shape[1]-1), mode='constant')
  x_sum=xt_p1
  for i in range(1,x_train.shape[1]):
    xt_t = xt[0,0:i+1]
    xt_pt=  np.pad(xt_t, (0, xt.shape[1]-xt_t.shape[0]), mode='constant')

    x_sum=np.vstack((x_sum, xt_pt))
  return x_sum

#padding time shift right -shift right =1 prepare the squence for decoder usinhe previous time step
def padding_full(x_pad,shift=1):
  xt=x_pad
  if (shift>0):
    ap=np.zeros((xt.shape[0],shift))
    xt=np.concatenate((ap,xt), axis=1)

  xt_1 = xt[0,0:1]
  xt_p1=  np.pad(xt_1, (0, xt.shape[1]-1), mode='constant')
  x_sum=xt_p1
  for i in range(1,x_train.shape[1]):
    xt_t = xt[0,0:i+1]
    xt_pt=  np.pad(xt_t, (0, xt.shape[1]-xt_t.shape[0]), mode='constant')

    x_sum=np.vstack((x_sum, xt_pt))
  x_sum_train=x_sum

  for num_s in range(1,xt.shape[0]):
    xt_1 = xt[num_s,0:1]
    xt_p1=  np.pad(xt_1, (0, xt.shape[1]-1), mode='constant')
    x_sum=xt_p1
    for i in range(1,x_train.shape[1]):
      xt_t = xt[0,0:i+1]
      xt_pt=  np.pad(xt_t, (0, xt.shape[1]-xt_t.shape[0]), mode='constant')

      x_sum=np.vstack((x_sum, xt_pt))
    x_sum_train =np.vstack((x_sum_train, x_sum))

  return x_sum_train

def out_put(y_train): #prepare y_value each step
  y_t=y_train

  y_sum=y_t[0,0]

  for time in range(1,y_t.shape[1]):
    y_sum=np.vstack((y_sum,y_t[0,time]))
  ysum_t=y_sum

  for nums in range(1,y_t.shape[0]):
    y_sum=y_t[nums,0]
    for time in range(1,y_t.shape[1]):
      y_sum=np.vstack((y_sum,y_t[0,time]))

    ysum_t=np.vstack((ysum_t,y_sum))
  return ysum_t




x_f=encoder_f(x_feature,28)
x_train_encoder=encoder_x(X_train_CNN)
y_decode=padding_full(x_pad=y_train, shift=1)
y_decode = np.delete (y_decode, -1, axis=1)
y_train=out_put(y_train)

# %%
#split data
X_train, X_test, X_feature_train, X_feature_test, Y_train, Y_test, y_d_train,y_d_test = train_test_split(x_train_encoder, x_f, y_train, y_decode,random_state=1,test_size=0.2)

# %%
#Model generation part
#import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Dense, Conv1D, Flatten, concatenate,Reshape, Dropout,Bidirectional,LayerNormalization
from keras.layers import MaxPooling1D
from keras.layers import LSTM, Dense
from keras.metrics import MeanAbsolutePercentageError
from keras import *
from keras.optimizers import Adam
import keras_nlp
#from attention import Attention




def transformer_encoder(inputs, head_size, num_heads, ff_dim,
                        dropout=0.2, attention_axes=None):
  """
  Creates a single transformer block.
  """
  x = layers.LayerNormalization(epsilon=1e-6)(inputs)
  x = layers.MultiHeadAttention(
      key_dim=head_size, num_heads=num_heads, dropout=dropout,
      attention_axes=attention_axes
      )(x, x)
  x = layers.Dropout(dropout)(x)
  res = x + inputs

    # Feed Forward Part
  x = layers.LayerNormalization(epsilon=1e-6)(res)
  x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
  x = layers.Dropout(dropout)(x)
  x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
  return x + res

def CNN_model(cnn_input_shape):
  # Create the CNN model
  cnn_input = Input(shape=cnn_input_shape,name='CNN_input')
  input = keras_nlp.layers.PositionEmbedding(sequence_length=cnn_input_shape[0])(cnn_input)

  layer=transformer_encoder(input, head_size=24, num_heads=10, ff_dim=2,
                        dropout=0.2, attention_axes=None)
  cnn_output = Flatten()(layer)
  cnn_output = Dense(50, activation='linear')(cnn_output)

  cnn_model = Model(inputs=cnn_input, outputs=cnn_output,name='CNN_model')
  return cnn_model

def LSTM_model_attention(dense_input_shape):
  # Create the dense model
  # Use the function parameter as the input shape
  dense_input = Input(shape=dense_input_shape,name='LSTM_input')
  layer=transformer_encoder(dense_input, head_size=24, num_heads=10, ff_dim=2,
                        dropout=0.2,squences=True)(layer)

  head_size=64
  num_heads=10
  ff_dim=2
  num_trans_blocks=12
  dropout=0.1
  attention_axes=1
  x = layers.LayerNormalization(epsilon=1e-6)(dense_output)
  x = layers.LayerNormalization(epsilon=1e-6)( x)
  x = layers.MultiHeadAttention(
      key_dim=head_size, num_heads=num_heads, dropout=dropout,
      attention_axes=attention_axes
      )(x, x)
  x = layers.Dropout(0.1)(x)
  res = x+dense_output
  #dense_output = Attention(units=32)(dense_output)
  layer = Flatten()(res)

  dense_output = Dense(200, activation='sigmoid')(layer)
  dense_output = Dense(50, activation='linear')(layer)

def LSTM_model(dense_input_shape):
  # Create the dense model
  # Use the function parameter as the input shape
  dense_input = Input(shape=dense_input_shape,name='LSTM_input')
  layer=transformer_encoder(dense_input, head_size=24, num_heads=10, ff_dim=2,
                        dropout=0.2, attention_axes=None)

  dense_output = LSTM(100,return_sequences=True)(layer)

  layer = Flatten()(dense_output)

  dense_output = Dense(200, activation='sigmoid')(layer)
  dense_output = Dense(50, activation='linear')(layer)
  #dense_output=  LayerNormalization(epsilon=1e-6)(dense_output)

  dense_model = Model(inputs=dense_input, outputs=dense_output,name='LSTM_model')
  return dense_model

def encoding_model(LSTM_model,cnn_model,latent_dim):
  combined_input_cnn = cnn_model.output
  combined_input_LSTM = LSTM_model.output
  combined_input = concatenate([combined_input_LSTM,combined_input_cnn])
  layer=Dense(200, activation='sigmoid')(combined_input)
  combined_output = Dense(latent_dim, activation='linear')(layer)
  combined_model = Model(inputs=[LSTM_model.input,cnn_model.input], outputs=combined_output,name='encoding_model')
  return combined_model

def decoding_model1(latent_dim,feature_dim,time_step):
  inputs_l = Input(shape=latent_dim, name='latent')
  inputs_f = Input(shape=feature_dim, name='feature')
  layerf_int=  dense_output = Dense(40, activation='sigmoid')(inputs_f)
  layerfeature=  dense_output = Dense(latent_dim, activation='sigmoid')(layerf_int)
  combined_input = concatenate([inputs_l, layerfeature],name='combind_feature')
  layer=Dense(200, activation='sigmoid')(combined_input)
  layer=Dense(100, activation='tanh')(layer)
  layer=Dense(time_step, activation='tanh')(layer)
  layer=Reshape((time_step,1))(layer)
  LSTM_out =  LSTM(1,return_sequences=True)(layer)
  output=LSTM_out[:,:,0]


  #dense_output = Dense(time_step, activation='linear')(layer)

  model = Model([inputs_l,inputs_f], outputs=output,name='decoding_model')
  return model

def decoding_model_transformer(latent_dim,feature_dim,time_step):
  inputs_l = Input(shape=latent_dim, name='latent') #from decoder

  inputs_f = Input(shape=feature_dim, name='feature')
  layerf_int=  Dense(40, activation='sigmoid')(inputs_f)
  layerfeature=  Dense(latent_dim, activation='sigmoid')(layerf_int)

  input_lag=Input(shape=(time_step,1), name='lag_input')
  input = keras_nlp.layers.PositionEmbedding(sequence_length=time_step)(input_lag)
  x = layers.LayerNormalization(epsilon=1e-6)(input)

  layer=transformer_encoder(x, head_size=24, num_heads=10, ff_dim=2,dropout=0, attention_axes=None)
  cnn_output = Flatten()(layer)
  layer = Dense(50, activation='linear')(cnn_output)

  #layer = LSTM(20)(input_lag)
  layer_LSTM=  Dense(latent_dim, activation='sigmoid')(layer)

  combined_input = concatenate([inputs_l, layerfeature,layer_LSTM],name='combind_feature')
  layer=Dropout(0.2)(combined_input)
  layer=Dense(30, activation='sigmoid')(layer)
  layer=Dense(5, activation='sigmoid')(layer)

  dense_output = Dense(1, activation='linear')(layer)
  output=dense_output
  model = Model([inputs_l,inputs_f,input_lag], outputs=output,name='decoding_model')
  return model

def decoding_model(latent_dim,feature_dim,time_step):
  inputs_l = Input(shape=latent_dim, name='latent') #from decoder

  inputs_f = Input(shape=feature_dim, name='feature')
  layerf_int=  Dense(40, activation='sigmoid')(inputs_f)
  layerfeature=  Dense(latent_dim, activation='sigmoid')(layerf_int)

  input_lag=Input(shape=(time_step,1), name='lag_input')

  layer = LSTM(100,return_sequences=True)(input_lag)
  layer = Flatten()(layer)
  layer= Dense(40, activation='sigmoid')(layer)
  layer_LSTM=  Dense(latent_dim, activation='sigmoid')(layer)



  combined_input = concatenate([inputs_l, layerfeature,layer_LSTM],name='combind_feature')
  layer=Dropout(0.2)(combined_input)
  layer=Dense(30, activation='sigmoid')(layer)
  layer=Dense(5, activation='sigmoid')(layer)

  dense_output = Dense(1, activation='linear')(layer)
  output=dense_output
  model = Model([inputs_l,inputs_f,input_lag], outputs=output,name='decoding_model')
  return model

def transformer(encoding_model,decoding_model,feature_dim):
  inputs_f = Input(shape=feature_dim, name='feature')
  input_lag=Input(shape=(None,1), name='lag_input')

  inputs_l=encoding_model.output
  print(inputs_l)
  outputs = decoding_model([inputs_l,inputs_f,input_lag])
  print(outputs)
  model = Model(inputs=[inputs_f,encoding_model.input,input_lag], outputs=outputs,name='Transformer')
  return model



# Compile and summarize the combined model
#Main program

dense_input_shape = (X_train.shape[1])
cnn_input_shape = (X_train.shape[1],X_train.shape[2])
LSTM_input_shape=(X_train.shape[1],X_train.shape[2])


feature_dim=X_feature.shape[1]
latent_dim=16
time_step=X_train.shape[1]
model_cnn=CNN_model(cnn_input_shape)
model_lstm= LSTM_model(LSTM_input_shape)

#model_combind=combind_model2(model_lstm,model_cnn,y_train)
model_encoding=encoding_model(model_lstm,model_cnn,latent_dim)
model_decoding=decoding_model(latent_dim,feature_dim,time_step)
model_decoding_transformer=decoding_model_transformer(latent_dim,feature_dim,time_step)

model_transform=transformer(model_encoding,model_decoding,feature_dim)
#adam.learning_rate=0.001
model_transform.compile(optimizer='adam', loss='mse', metrics=['mae','mape'])
model_transform.summary()


#from tensorflow.keras.callbacks import ModelCheckpoint
#checkpoint = ModelCheckpoint('model_best_weights.h5', monitor='loss', save_best_only=True)



history=model_transform.fit([X_feature_train,X_train, X_train,y_d_train],
                            Y_train, epochs=2000, batch_size=30,validation_data=([X_feature_test,X_test,X_test,y_d_test], Y_test))
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 16), dtype=tf.float32, name=None), name='dense_186/BiasAdd:0', description="created by layer 'dense_186'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='decoding_model/dense_193/BiasAdd:0', description="created by layer 'decoding_model'")
# Model: "Transformer"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  LSTM_input (InputLayer)     [(None, 28, 4)]              0         []
#
#  CNN_input (InputLayer)      [(None, 28, 4)]              0         []
#
#  layer_normalization_62 (La  (None, 28, 4)                8         ['LSTM_input[0][0]']
#  yerNormalization)
#
#  position_embedding_18 (Pos  (None, 28, 4)                112       ['CNN_input[0][0]']
#  itionEmbedding)
#
#  multi_head_attention_30 (M  (None, 28, 4)                4564      ['layer_normalization_62[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_62[0][0]
#                                                                     ']
#
#  layer_normalization_60 (La  (None, 28, 4)                8         ['position_embedding_18[0][0]'
#  yerNormalization)                                                  ]
#
#  dropout_78 (Dropout)        (None, 28, 4)                0         ['multi_head_attention_30[0][0
#                                                                     ]']
#
#  multi_head_attention_29 (M  (None, 28, 4)                4564      ['layer_normalization_60[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_60[0][0]
#                                                                     ']
#
#  tf.__operators__.add_60 (T  (None, 28, 4)                0         ['dropout_78[0][0]',
#  FOpLambda)                                                          'LSTM_input[0][0]']
#
#  dropout_76 (Dropout)        (None, 28, 4)                0         ['multi_head_attention_29[0][0
#                                                                     ]']
#
#  layer_normalization_63 (La  (None, 28, 4)                8         ['tf.__operators__.add_60[0][0
#  yerNormalization)                                                  ]']
#
#  tf.__operators__.add_58 (T  (None, 28, 4)                0         ['dropout_76[0][0]',
#  FOpLambda)                                                          'position_embedding_18[0][0]'
#                                                                     ]
#
#  conv1d_60 (Conv1D)          (None, 28, 2)                10        ['layer_normalization_63[0][0]
#                                                                     ']
#
#  layer_normalization_61 (La  (None, 28, 4)                8         ['tf.__operators__.add_58[0][0
#  yerNormalization)                                                  ]']
#
#  dropout_79 (Dropout)        (None, 28, 2)                0         ['conv1d_60[0][0]']
#
#  conv1d_58 (Conv1D)          (None, 28, 2)                10        ['layer_normalization_61[0][0]
#                                                                     ']
#
#  conv1d_61 (Conv1D)          (None, 28, 4)                12        ['dropout_79[0][0]']
#
#  dropout_77 (Dropout)        (None, 28, 2)                0         ['conv1d_58[0][0]']
#
#  tf.__operators__.add_61 (T  (None, 28, 4)                0         ['conv1d_61[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_60[0][0
#                                                                     ]']
#
#  conv1d_59 (Conv1D)          (None, 28, 4)                12        ['dropout_77[0][0]']
#
#  lstm_20 (LSTM)              (None, 28, 100)              42000     ['tf.__operators__.add_61[0][0
#                                                                     ]']
#
#  tf.__operators__.add_59 (T  (None, 28, 4)                0         ['conv1d_59[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_58[0][0
#                                                                     ]']
#
#  flatten_30 (Flatten)        (None, 2800)                 0         ['lstm_20[0][0]']
#
#  flatten_29 (Flatten)        (None, 112)                  0         ['tf.__operators__.add_59[0][0
#                                                                     ]']
#
#  dense_184 (Dense)           (None, 50)                   140050    ['flatten_30[0][0]']
#
#  dense_182 (Dense)           (None, 50)                   5650      ['flatten_29[0][0]']
#
#  concatenate_10 (Concatenat  (None, 100)                  0         ['dense_184[0][0]',
#  e)                                                                  'dense_182[0][0]']
#
#  dense_185 (Dense)           (None, 200)                  20200     ['concatenate_10[0][0]']
#
#  dense_186 (Dense)           (None, 16)                   3216      ['dense_185[0][0]']
#
#  feature (InputLayer)        [(None, 3)]                  0         []
#
#  lag_input (InputLayer)      [(None, None, 1)]            0         []
#
#  decoding_model (Functional  (None, 1)                    155943    ['dense_186[0][0]',
#  )                                                                   'feature[0][0]',
#                                                                      'lag_input[0][0]']
#
# ==================================================================================================
# Total params: 376375 (1.44 MB)
# Trainable params: 376375 (1.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/2000
# 26/26 [==============================] - 12s 97ms/step - loss: 0.8816 - mae: 0.8128 - mape: 118.8489 - val_loss: 0.8674 - val_mae: 0.7449 - val_mape: 93.5095
# Epoch 2/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.6985 - mae: 0.6853 - mape: 91.0208 - val_loss: 0.8702 - val_mae: 0.7079 - val_mape: 86.0258
# Epoch 3/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.6856 - mae: 0.6578 - mape: 87.5840 - val_loss: 0.8783 - val_mae: 0.6995 - val_mape: 86.4142
# Epoch 4/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.6818 - mae: 0.6481 - mape: 87.0816 - val_loss: 0.8796 - val_mae: 0.6984 - val_mape: 86.4637
# Epoch 5/2000
# 26/26 [==============================] - 2s 72ms/step - loss: 0.6839 - mae: 0.6458 - mape: 87.4769 - val_loss: 0.8834 - val_mae: 0.6959 - val_mape: 86.7497
# Epoch 6/2000
# 26/26 [==============================] - 3s 107ms/step - loss: 0.6838 - mae: 0.6463 - mape: 87.3242 - val_loss: 0.8803 - val_mae: 0.6978 - val_mape: 86.4912
# Epoch 7/2000
# 26/26 [==============================] - 3s 97ms/step - loss: 0.6820 - mae: 0.6423 - mape: 87.7033 - val_loss: 0.8869 - val_mae: 0.6952 - val_mape: 87.5410
# Epoch 8/2000
# 26/26 [==============================] - 2s 59ms/step - loss: 0.6815 - mae: 0.6447 - mape: 87.4921 - val_loss: 0.8813 - val_mae: 0.6970 - val_mape: 86.5315
# Epoch 9/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.6828 - mae: 0.6458 - mape: 87.8195 - val_loss: 0.8837 - val_mae: 0.6958 - val_mape: 86.8282
# Epoch 10/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.6839 - mae: 0.6459 - mape: 87.4928 - val_loss: 0.8822 - val_mae: 0.6965 - val_mape: 86.5776
# Epoch 11/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.6835 - mae: 0.6428 - mape: 87.6940 - val_loss: 0.8844 - val_mae: 0.6956 - val_mape: 86.9708
# Epoch 12/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.6844 - mae: 0.6462 - mape: 87.2492 - val_loss: 0.8788 - val_mae: 0.6969 - val_mape: 86.2733
# Epoch 13/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.6820 - mae: 0.6422 - mape: 87.5217 - val_loss: 0.8841 - val_mae: 0.6938 - val_mape: 86.5931
# Epoch 14/2000
# 26/26 [==============================] - 3s 103ms/step - loss: 0.6811 - mae: 0.6419 - mape: 87.1835 - val_loss: 0.8800 - val_mae: 0.6968 - val_mape: 86.2961
# Epoch 15/2000
# 26/26 [==============================] - 3s 107ms/step - loss: 0.6798 - mae: 0.6454 - mape: 86.9583 - val_loss: 0.8758 - val_mae: 0.6937 - val_mape: 85.5305
# Epoch 16/2000
# 26/26 [==============================] - 2s 66ms/step - loss: 0.6761 - mae: 0.6439 - mape: 86.0565 - val_loss: 0.8766 - val_mae: 0.6913 - val_mape: 85.7849
# Epoch 17/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.6720 - mae: 0.6341 - mape: 85.6699 - val_loss: 0.8699 - val_mae: 0.6873 - val_mape: 84.4734
# Epoch 18/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.6639 - mae: 0.6351 - mape: 84.5496 - val_loss: 0.8753 - val_mae: 0.6801 - val_mape: 85.8784
# Epoch 19/2000
# 26/26 [==============================] - 2s 58ms/step - loss: 0.6425 - mae: 0.6070 - mape: 80.9538 - val_loss: 0.8130 - val_mae: 0.6469 - val_mape: 74.4823
# Epoch 20/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.6094 - mae: 0.5831 - mape: 77.4980 - val_loss: 0.8298 - val_mae: 0.6278 - val_mape: 81.7383
# Epoch 21/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.5902 - mae: 0.5438 - mape: 71.4402 - val_loss: 0.8160 - val_mae: 0.6068 - val_mape: 78.9318
# Epoch 22/2000
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5968 - mae: 0.5386 - mape: 73.6260 - val_loss: 0.8209 - val_mae: 0.5930 - val_mape: 75.4371
# Epoch 23/2000
# 26/26 [==============================] - 3s 108ms/step - loss: 0.5718 - mae: 0.5015 - mape: 63.2395 - val_loss: 0.8060 - val_mae: 0.5742 - val_mape: 70.5518
# Epoch 24/2000
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5573 - mae: 0.4936 - mape: 61.1893 - val_loss: 0.8280 - val_mae: 0.5770 - val_mape: 79.4534
# Epoch 25/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.5649 - mae: 0.4961 - mape: 65.5820 - val_loss: 0.7196 - val_mae: 0.5540 - val_mape: 62.7634
# Epoch 26/2000
# 26/26 [==============================] - 2s 59ms/step - loss: 0.5145 - mae: 0.5169 - mape: 72.3238 - val_loss: 0.6276 - val_mae: 0.5452 - val_mape: 83.7542
# Epoch 27/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.4859 - mae: 0.4982 - mape: 77.2551 - val_loss: 0.7891 - val_mae: 0.5273 - val_mape: 68.1506
# Epoch 28/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.4155 - mae: 0.4488 - mape: 68.2266 - val_loss: 0.6420 - val_mae: 0.4800 - val_mape: 65.9137
# Epoch 29/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.4685 - mae: 0.4772 - mape: 79.6729 - val_loss: 0.6411 - val_mae: 0.6452 - val_mape: 111.5939
# Epoch 30/2000
# 26/26 [==============================] - 2s 74ms/step - loss: 0.4051 - mae: 0.4274 - mape: 65.8201 - val_loss: 0.4559 - val_mae: 0.4037 - val_mape: 54.6587
# Epoch 31/2000
# 26/26 [==============================] - 3s 101ms/step - loss: 0.3628 - mae: 0.3881 - mape: 58.2709 - val_loss: 0.4244 - val_mae: 0.3737 - val_mape: 51.5842
# Epoch 32/2000
# 26/26 [==============================] - 3s 100ms/step - loss: 0.3048 - mae: 0.3421 - mape: 55.4967 - val_loss: 0.4232 - val_mae: 0.3595 - val_mape: 46.0473
# Epoch 33/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.2900 - mae: 0.3357 - mape: 55.0216 - val_loss: 0.3637 - val_mae: 0.3769 - val_mape: 62.7526
# Epoch 34/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.3050 - mae: 0.3534 - mape: 60.5970 - val_loss: 0.3632 - val_mae: 0.3984 - val_mape: 78.8847
# Epoch 35/2000
# 26/26 [==============================] - 2s 65ms/step - loss: 0.2721 - mae: 0.3329 - mape: 58.8461 - val_loss: 0.3450 - val_mae: 0.3888 - val_mape: 75.0304
# Epoch 36/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.2478 - mae: 0.3179 - mape: 56.5992 - val_loss: 0.2931 - val_mae: 0.3229 - val_mape: 49.7943
# Epoch 37/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.2348 - mae: 0.3039 - mape: 51.8750 - val_loss: 0.3054 - val_mae: 0.3514 - val_mape: 64.3135
# Epoch 38/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.2350 - mae: 0.3075 - mape: 55.3587 - val_loss: 0.2881 - val_mae: 0.3250 - val_mape: 56.8148
# Epoch 39/2000
# 26/26 [==============================] - 3s 133ms/step - loss: 0.2310 - mae: 0.3142 - mape: 57.3997 - val_loss: 0.2635 - val_mae: 0.3105 - val_mape: 47.7340
# Epoch 40/2000
# 26/26 [==============================] - 3s 103ms/step - loss: 0.2140 - mae: 0.2925 - mape: 50.2693 - val_loss: 0.2570 - val_mae: 0.3148 - val_mape: 54.6451
# Epoch 41/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.2058 - mae: 0.2842 - mape: 50.9297 - val_loss: 0.2409 - val_mae: 0.2920 - val_mape: 46.4224
# Epoch 42/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.2001 - mae: 0.2806 - mape: 50.9540 - val_loss: 0.2428 - val_mae: 0.3008 - val_mape: 47.2819
# Epoch 43/2000
# 26/26 [==============================] - 2s 59ms/step - loss: 0.2061 - mae: 0.2909 - mape: 53.3975 - val_loss: 0.2309 - val_mae: 0.3022 - val_mape: 47.8424
# Epoch 44/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.1926 - mae: 0.2714 - mape: 50.6336 - val_loss: 0.2148 - val_mae: 0.2732 - val_mape: 42.6759
# Epoch 45/2000
# 26/26 [==============================] - 2s 58ms/step - loss: 0.1849 - mae: 0.2646 - mape: 48.1223 - val_loss: 0.2165 - val_mae: 0.2870 - val_mape: 53.1684
# Epoch 46/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.1749 - mae: 0.2592 - mape: 45.1070 - val_loss: 0.2028 - val_mae: 0.2737 - val_mape: 39.8639
# Epoch 47/2000
# 26/26 [==============================] - 2s 97ms/step - loss: 0.1842 - mae: 0.2663 - mape: 46.9682 - val_loss: 0.2055 - val_mae: 0.2755 - val_mape: 49.9428
# Epoch 48/2000
# 26/26 [==============================] - 3s 111ms/step - loss: 0.1715 - mae: 0.2663 - mape: 47.6511 - val_loss: 0.1843 - val_mae: 0.2473 - val_mape: 39.4425
# Epoch 49/2000
# 26/26 [==============================] - 2s 69ms/step - loss: 0.1588 - mae: 0.2485 - mape: 43.5227 - val_loss: 0.1776 - val_mae: 0.2502 - val_mape: 37.3507
# Epoch 50/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.1568 - mae: 0.2473 - mape: 44.2477 - val_loss: 0.1824 - val_mae: 0.2656 - val_mape: 40.0829
# Epoch 51/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.1481 - mae: 0.2403 - mape: 40.8946 - val_loss: 0.1598 - val_mae: 0.2372 - val_mape: 36.0779
# Epoch 52/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.1489 - mae: 0.2394 - mape: 41.3642 - val_loss: 0.1542 - val_mae: 0.2324 - val_mape: 36.7238
# Epoch 53/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.1385 - mae: 0.2219 - mape: 35.9922 - val_loss: 0.1516 - val_mae: 0.2420 - val_mape: 40.3000
# Epoch 54/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.1305 - mae: 0.2241 - mape: 38.0125 - val_loss: 0.1419 - val_mae: 0.2294 - val_mape: 33.1024
# Epoch 55/2000
# 26/26 [==============================] - 2s 88ms/step - loss: 0.1348 - mae: 0.2282 - mape: 38.4573 - val_loss: 0.1501 - val_mae: 0.2503 - val_mape: 50.4878
# Epoch 56/2000
# 26/26 [==============================] - 3s 108ms/step - loss: 0.1273 - mae: 0.2259 - mape: 40.7374 - val_loss: 0.1388 - val_mae: 0.2304 - val_mape: 42.2939
# Epoch 57/2000
# 26/26 [==============================] - 2s 85ms/step - loss: 0.1288 - mae: 0.2233 - mape: 37.7851 - val_loss: 0.1310 - val_mae: 0.2087 - val_mape: 36.3206
# Epoch 58/2000
# 26/26 [==============================] - 2s 66ms/step - loss: 0.1315 - mae: 0.2257 - mape: 40.0598 - val_loss: 0.1196 - val_mae: 0.1971 - val_mape: 31.7545
# Epoch 59/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.1159 - mae: 0.2074 - mape: 34.9394 - val_loss: 0.1220 - val_mae: 0.2010 - val_mape: 36.2070
# Epoch 60/2000
# 26/26 [==============================] - 2s 59ms/step - loss: 0.1127 - mae: 0.2044 - mape: 34.7066 - val_loss: 0.1205 - val_mae: 0.2139 - val_mape: 40.2592
# Epoch 61/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.1148 - mae: 0.2106 - mape: 36.4742 - val_loss: 0.1183 - val_mae: 0.2062 - val_mape: 37.7322
# Epoch 62/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.1085 - mae: 0.2017 - mape: 34.8933 - val_loss: 0.1061 - val_mae: 0.1901 - val_mape: 34.4395
# Epoch 63/2000
# 26/26 [==============================] - 2s 80ms/step - loss: 0.1069 - mae: 0.2020 - mape: 34.4122 - val_loss: 0.1066 - val_mae: 0.1899 - val_mape: 34.0932
# Epoch 64/2000
# 26/26 [==============================] - 3s 107ms/step - loss: 0.1037 - mae: 0.1988 - mape: 34.6968 - val_loss: 0.1164 - val_mae: 0.2226 - val_mape: 46.3911
# Epoch 65/2000
# 26/26 [==============================] - 2s 92ms/step - loss: 0.1039 - mae: 0.1933 - mape: 34.5932 - val_loss: 0.0927 - val_mae: 0.1796 - val_mape: 27.8789
# Epoch 66/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0938 - mae: 0.1790 - mape: 31.2054 - val_loss: 0.0965 - val_mae: 0.1922 - val_mape: 30.8615
# Epoch 67/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0972 - mae: 0.1865 - mape: 32.6868 - val_loss: 0.0920 - val_mae: 0.1761 - val_mape: 25.3795
# Epoch 68/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.1005 - mae: 0.1936 - mape: 34.5582 - val_loss: 0.0877 - val_mae: 0.1777 - val_mape: 25.6627
# Epoch 69/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0900 - mae: 0.1720 - mape: 29.0484 - val_loss: 0.0821 - val_mae: 0.1574 - val_mape: 26.0271
# Epoch 70/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0890 - mae: 0.1701 - mape: 27.7868 - val_loss: 0.0772 - val_mae: 0.1554 - val_mape: 23.6481
# Epoch 71/2000
# 26/26 [==============================] - 2s 76ms/step - loss: 0.0856 - mae: 0.1679 - mape: 28.5240 - val_loss: 0.0836 - val_mae: 0.1670 - val_mape: 23.3942
# Epoch 72/2000
# 26/26 [==============================] - 3s 107ms/step - loss: 0.0871 - mae: 0.1679 - mape: 28.7405 - val_loss: 0.0761 - val_mae: 0.1577 - val_mape: 23.7486
# Epoch 73/2000
# 26/26 [==============================] - 3s 99ms/step - loss: 0.0809 - mae: 0.1571 - mape: 26.2370 - val_loss: 0.0690 - val_mae: 0.1384 - val_mape: 21.3305
# Epoch 74/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0802 - mae: 0.1580 - mape: 26.4899 - val_loss: 0.0676 - val_mae: 0.1405 - val_mape: 20.2925
# Epoch 75/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0816 - mae: 0.1632 - mape: 28.9778 - val_loss: 0.0685 - val_mae: 0.1518 - val_mape: 25.0018
# Epoch 76/2000
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0871 - mae: 0.1735 - mape: 29.4356 - val_loss: 0.0667 - val_mae: 0.1432 - val_mape: 23.0928
# Epoch 77/2000
# 26/26 [==============================] - 3s 109ms/step - loss: 0.0793 - mae: 0.1585 - mape: 26.1669 - val_loss: 0.0627 - val_mae: 0.1343 - val_mape: 21.2010
# Epoch 78/2000
# 26/26 [==============================] - 3s 101ms/step - loss: 0.0761 - mae: 0.1534 - mape: 26.7630 - val_loss: 0.0632 - val_mae: 0.1436 - val_mape: 20.7794
# Epoch 79/2000
# 26/26 [==============================] - 3s 103ms/step - loss: 0.0770 - mae: 0.1567 - mape: 25.7323 - val_loss: 0.0593 - val_mae: 0.1235 - val_mape: 19.3609
# Epoch 80/2000
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0745 - mae: 0.1522 - mape: 26.1950 - val_loss: 0.0641 - val_mae: 0.1498 - val_mape: 25.6702
# Epoch 81/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0746 - mae: 0.1563 - mape: 27.9116 - val_loss: 0.0583 - val_mae: 0.1314 - val_mape: 21.9500
# Epoch 82/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0758 - mae: 0.1559 - mape: 26.5607 - val_loss: 0.0571 - val_mae: 0.1320 - val_mape: 22.2875
# Epoch 83/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0728 - mae: 0.1477 - mape: 24.5792 - val_loss: 0.0539 - val_mae: 0.1239 - val_mape: 19.5259
# Epoch 84/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0728 - mae: 0.1531 - mape: 27.0347 - val_loss: 0.0558 - val_mae: 0.1306 - val_mape: 19.1634
# Epoch 85/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0709 - mae: 0.1472 - mape: 24.3095 - val_loss: 0.0524 - val_mae: 0.1205 - val_mape: 18.0728
# Epoch 86/2000
# 26/26 [==============================] - 2s 67ms/step - loss: 0.0712 - mae: 0.1469 - mape: 23.5141 - val_loss: 0.0587 - val_mae: 0.1432 - val_mape: 25.3348
# Epoch 87/2000
# 26/26 [==============================] - 3s 108ms/step - loss: 0.0727 - mae: 0.1502 - mape: 25.4750 - val_loss: 0.0551 - val_mae: 0.1470 - val_mape: 22.8527
# Epoch 88/2000
# 26/26 [==============================] - 3s 103ms/step - loss: 0.0723 - mae: 0.1532 - mape: 25.6848 - val_loss: 0.0516 - val_mae: 0.1286 - val_mape: 22.3730
# Epoch 89/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0710 - mae: 0.1528 - mape: 26.9159 - val_loss: 0.0499 - val_mae: 0.1300 - val_mape: 21.7404
# Epoch 90/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.0688 - mae: 0.1468 - mape: 24.5701 - val_loss: 0.0490 - val_mae: 0.1271 - val_mape: 21.2010
# Epoch 91/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.0687 - mae: 0.1467 - mape: 23.8679 - val_loss: 0.0534 - val_mae: 0.1390 - val_mape: 25.1197
# Epoch 92/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0724 - mae: 0.1572 - mape: 28.2147 - val_loss: 0.0556 - val_mae: 0.1480 - val_mape: 26.7553
# Epoch 93/2000
# 26/26 [==============================] - 2s 65ms/step - loss: 0.0714 - mae: 0.1507 - mape: 24.6286 - val_loss: 0.0477 - val_mae: 0.1235 - val_mape: 21.4579
# Epoch 94/2000
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0682 - mae: 0.1460 - mape: 23.7579 - val_loss: 0.0460 - val_mae: 0.1173 - val_mape: 17.4972
# Epoch 95/2000
# 26/26 [==============================] - 3s 106ms/step - loss: 0.0678 - mae: 0.1455 - mape: 23.8062 - val_loss: 0.0462 - val_mae: 0.1253 - val_mape: 21.4212
# Epoch 96/2000
# 26/26 [==============================] - 3s 104ms/step - loss: 0.0639 - mae: 0.1380 - mape: 22.8471 - val_loss: 0.0441 - val_mae: 0.1163 - val_mape: 19.4215
# Epoch 97/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0695 - mae: 0.1437 - mape: 23.8428 - val_loss: 0.0448 - val_mae: 0.1175 - val_mape: 19.5375
# Epoch 98/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.0674 - mae: 0.1441 - mape: 23.9698 - val_loss: 0.0548 - val_mae: 0.1423 - val_mape: 24.8004
# Epoch 99/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0716 - mae: 0.1573 - mape: 27.3636 - val_loss: 0.0454 - val_mae: 0.1280 - val_mape: 23.9636
# Epoch 100/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0665 - mae: 0.1465 - mape: 25.3544 - val_loss: 0.0406 - val_mae: 0.1122 - val_mape: 18.8468
# Epoch 101/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0668 - mae: 0.1452 - mape: 25.2198 - val_loss: 0.0400 - val_mae: 0.1092 - val_mape: 17.8989
# Epoch 102/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0655 - mae: 0.1387 - mape: 24.6395 - val_loss: 0.0387 - val_mae: 0.1054 - val_mape: 16.6879
# Epoch 103/2000
# 26/26 [==============================] - 3s 107ms/step - loss: 0.0655 - mae: 0.1446 - mape: 24.5105 - val_loss: 0.0418 - val_mae: 0.1135 - val_mape: 17.5366
# Epoch 104/2000
# 26/26 [==============================] - 3s 117ms/step - loss: 0.0631 - mae: 0.1384 - mape: 22.8502 - val_loss: 0.0361 - val_mae: 0.1016 - val_mape: 16.2706
# Epoch 105/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0627 - mae: 0.1333 - mape: 22.0274 - val_loss: 0.0348 - val_mae: 0.0978 - val_mape: 15.1458
# Epoch 106/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0625 - mae: 0.1388 - mape: 23.2746 - val_loss: 0.0367 - val_mae: 0.1116 - val_mape: 20.0835
# Epoch 107/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0665 - mae: 0.1466 - mape: 25.7887 - val_loss: 0.0455 - val_mae: 0.1411 - val_mape: 32.9427
# Epoch 108/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0663 - mae: 0.1475 - mape: 25.9534 - val_loss: 0.0335 - val_mae: 0.1013 - val_mape: 16.6935
# Epoch 109/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0615 - mae: 0.1356 - mape: 22.9727 - val_loss: 0.0412 - val_mae: 0.1278 - val_mape: 20.6469
# Epoch 110/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0662 - mae: 0.1498 - mape: 27.6706 - val_loss: 0.0354 - val_mae: 0.1168 - val_mape: 21.0370
# Epoch 111/2000
# 26/26 [==============================] - 2s 96ms/step - loss: 0.0609 - mae: 0.1358 - mape: 23.8654 - val_loss: 0.0340 - val_mae: 0.1124 - val_mape: 20.0705
# Epoch 112/2000
# 26/26 [==============================] - 3s 109ms/step - loss: 0.0631 - mae: 0.1359 - mape: 23.7942 - val_loss: 0.0327 - val_mae: 0.1036 - val_mape: 18.2888
# Epoch 113/2000
# 26/26 [==============================] - 2s 72ms/step - loss: 0.0595 - mae: 0.1290 - mape: 21.0973 - val_loss: 0.0333 - val_mae: 0.1037 - val_mape: 18.8226
# Epoch 114/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0634 - mae: 0.1409 - mape: 24.2213 - val_loss: 0.0320 - val_mae: 0.1073 - val_mape: 18.7048
# Epoch 115/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0598 - mae: 0.1344 - mape: 23.1745 - val_loss: 0.0320 - val_mae: 0.1043 - val_mape: 19.6834
# Epoch 116/2000
# 26/26 [==============================] - 2s 68ms/step - loss: 0.0591 - mae: 0.1277 - mape: 21.1078 - val_loss: 0.0287 - val_mae: 0.0880 - val_mape: 14.0026
# Epoch 117/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.0597 - mae: 0.1303 - mape: 21.4258 - val_loss: 0.0301 - val_mae: 0.0979 - val_mape: 17.8564
# Epoch 118/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0598 - mae: 0.1298 - mape: 21.2681 - val_loss: 0.0285 - val_mae: 0.0967 - val_mape: 16.5180
# Epoch 119/2000
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0597 - mae: 0.1334 - mape: 22.4498 - val_loss: 0.0295 - val_mae: 0.0995 - val_mape: 17.1482
# Epoch 120/2000
# 26/26 [==============================] - 3s 107ms/step - loss: 0.0602 - mae: 0.1352 - mape: 22.8178 - val_loss: 0.0272 - val_mae: 0.0884 - val_mape: 14.8222
# Epoch 121/2000
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0575 - mae: 0.1268 - mape: 20.9297 - val_loss: 0.0283 - val_mae: 0.0906 - val_mape: 14.5098
# Epoch 122/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0580 - mae: 0.1312 - mape: 21.6964 - val_loss: 0.0272 - val_mae: 0.0910 - val_mape: 15.3538
# Epoch 123/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0559 - mae: 0.1239 - mape: 20.1575 - val_loss: 0.0263 - val_mae: 0.0831 - val_mape: 13.4585
# Epoch 124/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0586 - mae: 0.1304 - mape: 21.6881 - val_loss: 0.0268 - val_mae: 0.0932 - val_mape: 16.5938
# Epoch 125/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0573 - mae: 0.1283 - mape: 21.0506 - val_loss: 0.0294 - val_mae: 0.1042 - val_mape: 17.2997
# Epoch 126/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0591 - mae: 0.1338 - mape: 22.6143 - val_loss: 0.0297 - val_mae: 0.1067 - val_mape: 21.4708
# Epoch 127/2000
# 26/26 [==============================] - 2s 76ms/step - loss: 0.0581 - mae: 0.1319 - mape: 22.0100 - val_loss: 0.0257 - val_mae: 0.0934 - val_mape: 17.3876
# Epoch 128/2000
# 26/26 [==============================] - 3s 100ms/step - loss: 0.0541 - mae: 0.1262 - mape: 21.6501 - val_loss: 0.0300 - val_mae: 0.1063 - val_mape: 22.2467
# Epoch 129/2000
# 26/26 [==============================] - 3s 99ms/step - loss: 0.0554 - mae: 0.1222 - mape: 19.9309 - val_loss: 0.0252 - val_mae: 0.0932 - val_mape: 16.2819
# Epoch 130/2000
# 26/26 [==============================] - 2s 60ms/step - loss: 0.0547 - mae: 0.1278 - mape: 21.7586 - val_loss: 0.0245 - val_mae: 0.0837 - val_mape: 15.1818
# Epoch 131/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0560 - mae: 0.1251 - mape: 20.7920 - val_loss: 0.0235 - val_mae: 0.0855 - val_mape: 15.8768
# Epoch 132/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0565 - mae: 0.1266 - mape: 21.0221 - val_loss: 0.0257 - val_mae: 0.0893 - val_mape: 13.9875
# Epoch 133/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0558 - mae: 0.1264 - mape: 20.3989 - val_loss: 0.0233 - val_mae: 0.0810 - val_mape: 13.0199
# Epoch 134/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0558 - mae: 0.1273 - mape: 21.7430 - val_loss: 0.0265 - val_mae: 0.0951 - val_mape: 16.3684
# Epoch 135/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0579 - mae: 0.1305 - mape: 22.0574 - val_loss: 0.0229 - val_mae: 0.0851 - val_mape: 14.3031
# Epoch 136/2000
# 26/26 [==============================] - 3s 104ms/step - loss: 0.0557 - mae: 0.1284 - mape: 22.4161 - val_loss: 0.0219 - val_mae: 0.0803 - val_mape: 14.2026
# Epoch 137/2000
# 26/26 [==============================] - 3s 108ms/step - loss: 0.0557 - mae: 0.1254 - mape: 21.8879 - val_loss: 0.0233 - val_mae: 0.0921 - val_mape: 16.5297
# Epoch 138/2000
# 26/26 [==============================] - 2s 68ms/step - loss: 0.0590 - mae: 0.1317 - mape: 22.9957 - val_loss: 0.0221 - val_mae: 0.0806 - val_mape: 13.7306
# Epoch 139/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0575 - mae: 0.1300 - mape: 22.2915 - val_loss: 0.0223 - val_mae: 0.0893 - val_mape: 16.4130
# Epoch 140/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0549 - mae: 0.1248 - mape: 20.8597 - val_loss: 0.0212 - val_mae: 0.0794 - val_mape: 15.9895
# Epoch 141/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0557 - mae: 0.1269 - mape: 22.0672 - val_loss: 0.0265 - val_mae: 0.0946 - val_mape: 19.1478
# Epoch 142/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0576 - mae: 0.1261 - mape: 21.7639 - val_loss: 0.0220 - val_mae: 0.0856 - val_mape: 17.7809
# Epoch 143/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0567 - mae: 0.1232 - mape: 22.0141 - val_loss: 0.0226 - val_mae: 0.0827 - val_mape: 14.3955
# Epoch 144/2000
# 26/26 [==============================] - 2s 94ms/step - loss: 0.0534 - mae: 0.1199 - mape: 20.5131 - val_loss: 0.0239 - val_mae: 0.0912 - val_mape: 18.1641
# Epoch 145/2000
# 26/26 [==============================] - 3s 105ms/step - loss: 0.0541 - mae: 0.1213 - mape: 21.6309 - val_loss: 0.0217 - val_mae: 0.0834 - val_mape: 16.5737
# Epoch 146/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0543 - mae: 0.1211 - mape: 20.2612 - val_loss: 0.0199 - val_mae: 0.0753 - val_mape: 14.3415
# Epoch 147/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0587 - mae: 0.1283 - mape: 21.8314 - val_loss: 0.0200 - val_mae: 0.0786 - val_mape: 13.3266
# Epoch 148/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0566 - mae: 0.1251 - mape: 21.1134 - val_loss: 0.0195 - val_mae: 0.0754 - val_mape: 13.0650
# Epoch 149/2000
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0520 - mae: 0.1145 - mape: 18.8549 - val_loss: 0.0197 - val_mae: 0.0701 - val_mape: 11.9218
# Epoch 150/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0549 - mae: 0.1219 - mape: 19.8552 - val_loss: 0.0213 - val_mae: 0.0771 - val_mape: 13.2095
# Epoch 151/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0514 - mae: 0.1142 - mape: 18.9884 - val_loss: 0.0192 - val_mae: 0.0711 - val_mape: 12.6347
# Epoch 152/2000
# 26/26 [==============================] - 2s 94ms/step - loss: 0.0544 - mae: 0.1212 - mape: 20.9807 - val_loss: 0.0182 - val_mae: 0.0654 - val_mape: 11.8229
# Epoch 153/2000
# 26/26 [==============================] - 3s 111ms/step - loss: 0.0560 - mae: 0.1260 - mape: 23.2260 - val_loss: 0.0190 - val_mae: 0.0765 - val_mape: 15.1186
# Epoch 154/2000
# 26/26 [==============================] - 2s 75ms/step - loss: 0.0534 - mae: 0.1178 - mape: 19.7156 - val_loss: 0.0182 - val_mae: 0.0673 - val_mape: 11.8761
# Epoch 155/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0529 - mae: 0.1153 - mape: 18.8940 - val_loss: 0.0186 - val_mae: 0.0693 - val_mape: 12.2555
# Epoch 156/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0563 - mae: 0.1256 - mape: 21.4458 - val_loss: 0.0215 - val_mae: 0.0800 - val_mape: 14.4595
# Epoch 157/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0545 - mae: 0.1178 - mape: 19.4277 - val_loss: 0.0198 - val_mae: 0.0748 - val_mape: 12.8836
# Epoch 158/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0555 - mae: 0.1233 - mape: 21.5381 - val_loss: 0.0204 - val_mae: 0.0755 - val_mape: 14.2825
# Epoch 159/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0532 - mae: 0.1194 - mape: 20.9271 - val_loss: 0.0178 - val_mae: 0.0713 - val_mape: 13.5476
# Epoch 160/2000
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0531 - mae: 0.1148 - mape: 19.2493 - val_loss: 0.0180 - val_mae: 0.0698 - val_mape: 13.0569
# Epoch 161/2000
# 26/26 [==============================] - 3s 111ms/step - loss: 0.0511 - mae: 0.1124 - mape: 19.8625 - val_loss: 0.0175 - val_mae: 0.0631 - val_mape: 12.1440
# Epoch 162/2000
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0531 - mae: 0.1141 - mape: 18.8221 - val_loss: 0.0161 - val_mae: 0.0568 - val_mape: 10.2139
# Epoch 163/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0523 - mae: 0.1145 - mape: 18.9475 - val_loss: 0.0184 - val_mae: 0.0670 - val_mape: 13.9803
# Epoch 164/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0517 - mae: 0.1138 - mape: 19.3306 - val_loss: 0.0190 - val_mae: 0.0721 - val_mape: 15.6892
# Epoch 165/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0522 - mae: 0.1143 - mape: 19.3910 - val_loss: 0.0164 - val_mae: 0.0627 - val_mape: 12.1804
# Epoch 166/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0518 - mae: 0.1130 - mape: 19.8063 - val_loss: 0.0200 - val_mae: 0.0825 - val_mape: 18.9864
# Epoch 167/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0537 - mae: 0.1173 - mape: 20.0702 - val_loss: 0.0191 - val_mae: 0.0754 - val_mape: 15.5223
# Epoch 168/2000
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0522 - mae: 0.1151 - mape: 19.9107 - val_loss: 0.0187 - val_mae: 0.0748 - val_mape: 18.4216
# Epoch 169/2000
# 26/26 [==============================] - 3s 109ms/step - loss: 0.0531 - mae: 0.1202 - mape: 21.4743 - val_loss: 0.0174 - val_mae: 0.0637 - val_mape: 13.7284
# Epoch 170/2000
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0511 - mae: 0.1110 - mape: 18.8122 - val_loss: 0.0198 - val_mae: 0.0774 - val_mape: 17.6921
# Epoch 171/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0536 - mae: 0.1171 - mape: 20.5294 - val_loss: 0.0187 - val_mae: 0.0712 - val_mape: 15.1151
# Epoch 172/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0516 - mae: 0.1137 - mape: 19.2497 - val_loss: 0.0175 - val_mae: 0.0660 - val_mape: 12.9049
# Epoch 173/2000
# 26/26 [==============================] - 2s 68ms/step - loss: 0.0552 - mae: 0.1202 - mape: 20.9169 - val_loss: 0.0248 - val_mae: 0.0921 - val_mape: 23.8576
# Epoch 174/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0568 - mae: 0.1300 - mape: 25.5898 - val_loss: 0.0172 - val_mae: 0.0640 - val_mape: 13.2779
# Epoch 175/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0564 - mae: 0.1222 - mape: 21.3723 - val_loss: 0.0237 - val_mae: 0.1010 - val_mape: 23.4331
# Epoch 176/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0557 - mae: 0.1235 - mape: 22.4639 - val_loss: 0.0203 - val_mae: 0.0756 - val_mape: 15.0074
# Epoch 177/2000
# 26/26 [==============================] - 3s 109ms/step - loss: 0.0530 - mae: 0.1166 - mape: 20.7258 - val_loss: 0.0182 - val_mae: 0.0760 - val_mape: 15.1411
# Epoch 178/2000
# 26/26 [==============================] - 2s 95ms/step - loss: 0.0561 - mae: 0.1248 - mape: 21.7221 - val_loss: 0.0203 - val_mae: 0.0827 - val_mape: 16.0010
# Epoch 179/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0533 - mae: 0.1193 - mape: 20.6733 - val_loss: 0.0194 - val_mae: 0.0813 - val_mape: 19.0026
# Epoch 180/2000
# 26/26 [==============================] - 2s 65ms/step - loss: 0.0536 - mae: 0.1160 - mape: 20.4994 - val_loss: 0.0169 - val_mae: 0.0683 - val_mape: 14.4420
# Epoch 181/2000
# 26/26 [==============================] - 2s 65ms/step - loss: 0.0532 - mae: 0.1140 - mape: 19.3044 - val_loss: 0.0160 - val_mae: 0.0600 - val_mape: 11.8331
# Epoch 182/2000
# 26/26 [==============================] - 2s 66ms/step - loss: 0.0527 - mae: 0.1119 - mape: 18.8256 - val_loss: 0.0164 - val_mae: 0.0612 - val_mape: 12.4580
# Epoch 183/2000
# 26/26 [==============================] - 2s 66ms/step - loss: 0.0514 - mae: 0.1102 - mape: 18.8040 - val_loss: 0.0166 - val_mae: 0.0602 - val_mape: 12.3436
# Epoch 184/2000
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0515 - mae: 0.1118 - mape: 18.9964 - val_loss: 0.0149 - val_mae: 0.0523 - val_mape: 10.5106
# Epoch 185/2000
# 26/26 [==============================] - 3s 106ms/step - loss: 0.0520 - mae: 0.1129 - mape: 19.3400 - val_loss: 0.0164 - val_mae: 0.0597 - val_mape: 11.6864
# Epoch 186/2000
# 26/26 [==============================] - 2s 94ms/step - loss: 0.0525 - mae: 0.1147 - mape: 19.3319 - val_loss: 0.0224 - val_mae: 0.0916 - val_mape: 19.7544
# Epoch 187/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0505 - mae: 0.1092 - mape: 18.2591 - val_loss: 0.0171 - val_mae: 0.0641 - val_mape: 13.5533
# Epoch 188/2000
# 26/26 [==============================] - 2s 65ms/step - loss: 0.0503 - mae: 0.1107 - mape: 19.1764 - val_loss: 0.0160 - val_mae: 0.0608 - val_mape: 12.8861
# Epoch 189/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0499 - mae: 0.1081 - mape: 17.9172 - val_loss: 0.0153 - val_mae: 0.0547 - val_mape: 10.7785
# Epoch 190/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0510 - mae: 0.1091 - mape: 18.9386 - val_loss: 0.0180 - val_mae: 0.0708 - val_mape: 15.8383
# Epoch 191/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0545 - mae: 0.1188 - mape: 22.1222 - val_loss: 0.0165 - val_mae: 0.0581 - val_mape: 11.6070
# Epoch 192/2000
# 26/26 [==============================] - 2s 74ms/step - loss: 0.0541 - mae: 0.1142 - mape: 19.1598 - val_loss: 0.0168 - val_mae: 0.0642 - val_mape: 14.1072
# Epoch 193/2000
# 26/26 [==============================] - 3s 109ms/step - loss: 0.0521 - mae: 0.1118 - mape: 19.4883 - val_loss: 0.0174 - val_mae: 0.0631 - val_mape: 13.5877
# Epoch 194/2000
# 26/26 [==============================] - 3s 101ms/step - loss: 0.0549 - mae: 0.1223 - mape: 22.2853 - val_loss: 0.0187 - val_mae: 0.0661 - val_mape: 14.3473
# Epoch 195/2000
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0512 - mae: 0.1094 - mape: 19.5226 - val_loss: 0.0162 - val_mae: 0.0602 - val_mape: 11.8615
# Epoch 196/2000
# 26/26 [==============================] - 3s 105ms/step - loss: 0.0514 - mae: 0.1123 - mape: 19.4650 - val_loss: 0.0167 - val_mae: 0.0610 - val_mape: 14.2441
# Epoch 197/2000
# 26/26 [==============================] - 3s 97ms/step - loss: 0.0523 - mae: 0.1113 - mape: 19.2733 - val_loss: 0.0174 - val_mae: 0.0665 - val_mape: 13.7406
# Epoch 198/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0495 - mae: 0.1033 - mape: 17.6254 - val_loss: 0.0158 - val_mae: 0.0560 - val_mape: 11.1722
# Epoch 199/2000
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0509 - mae: 0.1076 - mape: 18.4650 - val_loss: 0.0161 - val_mae: 0.0585 - val_mape: 11.5619
# Epoch 200/2000
# 26/26 [==============================] - 3s 107ms/step - loss: 0.0510 - mae: 0.1077 - mape: 17.5145 - val_loss: 0.0148 - val_mae: 0.0468 - val_mape: 9.7341
# Epoch 201/2000
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0525 - mae: 0.1106 - mape: 18.5892 - val_loss: 0.0179 - val_mae: 0.0584 - val_mape: 10.7384
# Epoch 202/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0529 - mae: 0.1149 - mape: 19.5280 - val_loss: 0.0154 - val_mae: 0.0554 - val_mape: 11.0450
# Epoch 203/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0524 - mae: 0.1107 - mape: 18.9062 - val_loss: 0.0164 - val_mae: 0.0602 - val_mape: 12.6208
# Epoch 204/2000
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0527 - mae: 0.1135 - mape: 19.8674 - val_loss: 0.0167 - val_mae: 0.0573 - val_mape: 12.9366
# Epoch 205/2000
# 26/26 [==============================] - 2s 65ms/step - loss: 0.0512 - mae: 0.1076 - mape: 17.9331 - val_loss: 0.0160 - val_mae: 0.0533 - val_mape: 10.8083
# Epoch 206/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0501 - mae: 0.1074 - mape: 17.7426 - val_loss: 0.0177 - val_mae: 0.0707 - val_mape: 15.6473
# Epoch 207/2000
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0522 - mae: 0.1129 - mape: 19.4518 - val_loss: 0.0163 - val_mae: 0.0561 - val_mape: 10.8848
# Epoch 208/2000
# 26/26 [==============================] - 3s 103ms/step - loss: 0.0531 - mae: 0.1103 - mape: 18.8802 - val_loss: 0.0159 - val_mae: 0.0605 - val_mape: 12.6010
# Epoch 209/2000
# 26/26 [==============================] - 3s 97ms/step - loss: 0.0526 - mae: 0.1108 - mape: 18.3096 - val_loss: 0.0169 - val_mae: 0.0608 - val_mape: 12.8117
# Epoch 210/2000
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0552 - mae: 0.1180 - mape: 20.6947 - val_loss: 0.0155 - val_mae: 0.0506 - val_mape: 10.6627
# Epoch 211/2000
# 26/26 [==============================] - 2s 65ms/step - loss: 0.0526 - mae: 0.1153 - mape: 19.8553 - val_loss: 0.0171 - val_mae: 0.0652 - val_mape: 14.4303
# Epoch 212/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0518 - mae: 0.1095 - mape: 18.7582 - val_loss: 0.0196 - val_mae: 0.0720 - val_mape: 18.0990
# Epoch 213/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0528 - mae: 0.1136 - mape: 20.6327 - val_loss: 0.0164 - val_mae: 0.0601 - val_mape: 12.2051
# Epoch 214/2000
# 26/26 [==============================] - 2s 65ms/step - loss: 0.0516 - mae: 0.1105 - mape: 18.7243 - val_loss: 0.0147 - val_mae: 0.0478 - val_mape: 9.9191
# Epoch 215/2000
# 26/26 [==============================] - 2s 73ms/step - loss: 0.0515 - mae: 0.1100 - mape: 18.7366 - val_loss: 0.0199 - val_mae: 0.0728 - val_mape: 19.0375
# Epoch 216/2000
# 26/26 [==============================] - 3s 99ms/step - loss: 0.0512 - mae: 0.1106 - mape: 19.6144 - val_loss: 0.0149 - val_mae: 0.0502 - val_mape: 10.5040
# Epoch 217/2000
# 26/26 [==============================] - 3s 114ms/step - loss: 0.0508 - mae: 0.1057 - mape: 17.8823 - val_loss: 0.0163 - val_mae: 0.0559 - val_mape: 11.7825
# Epoch 218/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0507 - mae: 0.1076 - mape: 17.9508 - val_loss: 0.0151 - val_mae: 0.0473 - val_mape: 9.7978
# Epoch 219/2000
# 26/26 [==============================] - 2s 61ms/step - loss: 0.0505 - mae: 0.1090 - mape: 17.9205 - val_loss: 0.0166 - val_mae: 0.0616 - val_mape: 12.3590
# Epoch 220/2000
# 26/26 [==============================] - 2s 65ms/step - loss: 0.0502 - mae: 0.1075 - mape: 18.0288 - val_loss: 0.0158 - val_mae: 0.0504 - val_mape: 10.2190
# Epoch 221/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0506 - mae: 0.1098 - mape: 18.3629 - val_loss: 0.0153 - val_mae: 0.0470 - val_mape: 9.5303
# Epoch 222/2000
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0516 - mae: 0.1104 - mape: 18.3567 - val_loss: 0.0158 - val_mae: 0.0543 - val_mape: 13.3729
# Epoch 223/2000
# ...
# Epoch 1908/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0184 - mae: 0.0631 - mape: 11.4590 - val_loss: 0.0197 - val_mae: 0.0353 - val_mape: 7.4175
# Epoch 1909/2000
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0193 - mae: 0.0638 - mape: 12.4730 - val_loss: 0.0190 - val_mae: 0.0463 - val_mape: 11.1395
# Epoch 1910/2000
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0189 - mae: 0.0644 - mape: 13.1815 - val_loss: 0.0185 - val_mae: 0.0374 - val_mape: 7.5654
# Epoch 1911/2000
# 26/26 [==============================] - 3s 110ms/step - loss: 0.0194 - mae: 0.0690 - mape: 14.6137 - val_loss: 0.0187 - val_mae: 0.0366 - val_mape: 7.6350
# Epoch 1912/2000
# 26/26 [==============================] - 3s 108ms/step - loss: 0.0180 - mae: 0.0642 - mape: 12.1387 - val_loss: 0.0214 - val_mae: 0.0393 - val_mape: 8.3825
# Epoch 1913/2000
# 26/26 [==============================] - 3s 97ms/step - loss: 0.0217 - mae: 0.0705 - mape: 13.6886 - val_loss: 0.0190 - val_mae: 0.0392 - val_mape: 7.9066
# Epoch 1914/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0226 - mae: 0.0680 - mape: 13.1769 - val_loss: 0.0196 - val_mae: 0.0422 - val_mape: 9.7455
# Epoch 1915/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0225 - mae: 0.0698 - mape: 13.9244 - val_loss: 0.0237 - val_mae: 0.0584 - val_mape: 15.1176
# Epoch 1916/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0215 - mae: 0.0714 - mape: 13.6891 - val_loss: 0.0226 - val_mae: 0.0475 - val_mape: 10.6859
# Epoch 1917/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0225 - mae: 0.0723 - mape: 14.0114 - val_loss: 0.0226 - val_mae: 0.0565 - val_mape: 13.8771
# Epoch 1918/2000
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0205 - mae: 0.0830 - mape: 18.5033 - val_loss: 0.0232 - val_mae: 0.0655 - val_mape: 15.1706
# Epoch 1919/2000
# 26/26 [==============================] - 3s 104ms/step - loss: 0.0208 - mae: 0.0729 - mape: 14.1507 - val_loss: 0.0230 - val_mae: 0.0521 - val_mape: 12.0116
# Epoch 1920/2000
# 26/26 [==============================] - 3s 110ms/step - loss: 0.0212 - mae: 0.0671 - mape: 13.2415 - val_loss: 0.0231 - val_mae: 0.0422 - val_mape: 9.0187
# Epoch 1921/2000
# 26/26 [==============================] - 3s 96ms/step - loss: 0.0194 - mae: 0.0616 - mape: 12.2075 - val_loss: 0.0215 - val_mae: 0.0440 - val_mape: 9.4398
# Epoch 1922/2000
# 26/26 [==============================] - 2s 76ms/step - loss: 0.0215 - mae: 0.0708 - mape: 14.9008 - val_loss: 0.0254 - val_mae: 0.0413 - val_mape: 8.8965
# Epoch 1923/2000
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0168 - mae: 0.0618 - mape: 11.8996 - val_loss: 0.0221 - val_mae: 0.0421 - val_mape: 9.2182
# Epoch 1924/2000
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0192 - mae: 0.0647 - mape: 12.2691 - val_loss: 0.0218 - val_mae: 0.0409 - val_mape: 8.3883
# Epoch 1925/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0164 - mae: 0.0665 - mape: 13.8247 - val_loss: 0.0228 - val_mae: 0.0555 - val_mape: 14.1424
# Epoch 1926/2000
# 26/26 [==============================] - 3s 100ms/step - loss: 0.0206 - mae: 0.0710 - mape: 13.6445 - val_loss: 0.0230 - val_mae: 0.0446 - val_mape: 9.2611
# Epoch 1927/2000
# 26/26 [==============================] - 3s 113ms/step - loss: 0.0176 - mae: 0.0676 - mape: 13.5300 - val_loss: 0.0211 - val_mae: 0.0421 - val_mape: 9.2357
# Epoch 1928/2000
# 26/26 [==============================] - 3s 110ms/step - loss: 0.0165 - mae: 0.0608 - mape: 12.2514 - val_loss: 0.0224 - val_mae: 0.0422 - val_mape: 9.3972
# Epoch 1929/2000
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0158 - mae: 0.0632 - mape: 12.3412 - val_loss: 0.0236 - val_mae: 0.0417 - val_mape: 9.9888
# Epoch 1930/2000
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0198 - mae: 0.0689 - mape: 14.7827 - val_loss: 0.0240 - val_mae: 0.0423 - val_mape: 8.8861
# Epoch 1931/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0165 - mae: 0.0637 - mape: 12.5132 - val_loss: 0.0225 - val_mae: 0.0402 - val_mape: 8.7820
# Epoch 1932/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0195 - mae: 0.0686 - mape: 12.6763 - val_loss: 0.0203 - val_mae: 0.0387 - val_mape: 8.4994
# Epoch 1933/2000
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0165 - mae: 0.0653 - mape: 12.9062 - val_loss: 0.0255 - val_mae: 0.0535 - val_mape: 13.5076
# Epoch 1934/2000
# 26/26 [==============================] - 3s 102ms/step - loss: 0.0159 - mae: 0.0673 - mape: 13.2115 - val_loss: 0.0241 - val_mae: 0.0440 - val_mape: 9.6811
# Epoch 1935/2000
# 26/26 [==============================] - 3s 110ms/step - loss: 0.0190 - mae: 0.0683 - mape: 13.7157 - val_loss: 0.0260 - val_mae: 0.0460 - val_mape: 10.5083
# Epoch 1936/2000
# 26/26 [==============================] - 3s 113ms/step - loss: 0.0230 - mae: 0.0728 - mape: 14.8643 - val_loss: 0.0269 - val_mae: 0.0421 - val_mape: 9.0581
# Epoch 1937/2000
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0157 - mae: 0.0647 - mape: 13.2233 - val_loss: 0.0261 - val_mae: 0.0413 - val_mape: 8.7937
# Epoch 1938/2000
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0201 - mae: 0.0690 - mape: 14.6391 - val_loss: 0.0226 - val_mae: 0.0399 - val_mape: 8.3209
# Epoch 1939/2000
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0198 - mae: 0.0676 - mape: 12.8259 - val_loss: 0.0262 - val_mae: 0.0487 - val_mape: 10.5289
# Epoch 1940/2000
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0154 - mae: 0.0667 - mape: 13.6379 - val_loss: 0.0279 - val_mae: 0.0422 - val_mape: 9.3942
# Epoch 1941/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0205 - mae: 0.0653 - mape: 13.5459 - val_loss: 0.0268 - val_mae: 0.0420 - val_mape: 9.5313
# Epoch 1942/2000
# 26/26 [==============================] - 3s 109ms/step - loss: 0.0213 - mae: 0.0794 - mape: 18.0193 - val_loss: 0.0289 - val_mae: 0.0649 - val_mape: 15.2134
# Epoch 1943/2000
# 26/26 [==============================] - 3s 111ms/step - loss: 0.0175 - mae: 0.0707 - mape: 14.6621 - val_loss: 0.0274 - val_mae: 0.0556 - val_mape: 12.4972
# Epoch 1944/2000
# 26/26 [==============================] - 3s 110ms/step - loss: 0.0180 - mae: 0.0681 - mape: 13.2346 - val_loss: 0.0280 - val_mae: 0.0415 - val_mape: 8.9139
# Epoch 1945/2000
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0150 - mae: 0.0610 - mape: 11.7676 - val_loss: 0.0258 - val_mae: 0.0397 - val_mape: 8.7031
# Epoch 1946/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0152 - mae: 0.0601 - mape: 10.9406 - val_loss: 0.0291 - val_mae: 0.0430 - val_mape: 9.0361
# Epoch 1947/2000
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0166 - mae: 0.0658 - mape: 12.7449 - val_loss: 0.0281 - val_mae: 0.0463 - val_mape: 10.3170
# Epoch 1948/2000
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0170 - mae: 0.0644 - mape: 13.7985 - val_loss: 0.0222 - val_mae: 0.0398 - val_mape: 8.3041
# Epoch 1949/2000
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0196 - mae: 0.0692 - mape: 14.5490 - val_loss: 0.0230 - val_mae: 0.0411 - val_mape: 9.1854
# Epoch 1950/2000
# 26/26 [==============================] - 3s 107ms/step - loss: 0.0179 - mae: 0.0635 - mape: 12.3953 - val_loss: 0.0236 - val_mae: 0.0477 - val_mape: 11.6074
# Epoch 1951/2000
# 26/26 [==============================] - 3s 110ms/step - loss: 0.0180 - mae: 0.0673 - mape: 14.7227 - val_loss: 0.0241 - val_mae: 0.0415 - val_mape: 9.2467
# Epoch 1952/2000
# 26/26 [==============================] - 3s 106ms/step - loss: 0.0235 - mae: 0.0721 - mape: 14.0251 - val_loss: 0.0254 - val_mae: 0.0578 - val_mape: 13.5115
# Epoch 1953/2000
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0172 - mae: 0.0710 - mape: 15.1113 - val_loss: 0.0259 - val_mae: 0.0515 - val_mape: 12.3930
# Epoch 1954/2000
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0157 - mae: 0.0624 - mape: 12.5570 - val_loss: 0.0239 - val_mae: 0.0409 - val_mape: 9.3627
# Epoch 1955/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0184 - mae: 0.0649 - mape: 12.2043 - val_loss: 0.0269 - val_mae: 0.0428 - val_mape: 8.7271
# Epoch 1956/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0214 - mae: 0.0697 - mape: 14.0644 - val_loss: 0.0263 - val_mae: 0.0431 - val_mape: 8.4871
# Epoch 1957/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0146 - mae: 0.0612 - mape: 11.6611 - val_loss: 0.0260 - val_mae: 0.0457 - val_mape: 9.3970
# Epoch 1958/2000
# 26/26 [==============================] - 3s 110ms/step - loss: 0.0163 - mae: 0.0633 - mape: 12.5528 - val_loss: 0.0251 - val_mae: 0.0436 - val_mape: 8.7276
# Epoch 1959/2000
# 26/26 [==============================] - 3s 110ms/step - loss: 0.0155 - mae: 0.0631 - mape: 12.4329 - val_loss: 0.0235 - val_mae: 0.0413 - val_mape: 9.3746
# Epoch 1960/2000
# 26/26 [==============================] - 3s 113ms/step - loss: 0.0172 - mae: 0.0659 - mape: 13.9782 - val_loss: 0.0213 - val_mae: 0.0458 - val_mape: 10.3414
# Epoch 1961/2000
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0158 - mae: 0.0661 - mape: 12.5866 - val_loss: 0.0208 - val_mae: 0.0370 - val_mape: 7.9590
# Epoch 1962/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0163 - mae: 0.0623 - mape: 12.4195 - val_loss: 0.0242 - val_mae: 0.0411 - val_mape: 8.7588
# Epoch 1963/2000
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0143 - mae: 0.0619 - mape: 12.0587 - val_loss: 0.0262 - val_mae: 0.0544 - val_mape: 12.8244
# Epoch 1964/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0193 - mae: 0.0682 - mape: 13.2361 - val_loss: 0.0260 - val_mae: 0.0423 - val_mape: 9.1883
# Epoch 1965/2000
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0164 - mae: 0.0644 - mape: 13.3969 - val_loss: 0.0229 - val_mae: 0.0425 - val_mape: 9.2418
# Epoch 1966/2000
# 26/26 [==============================] - 3s 109ms/step - loss: 0.0168 - mae: 0.0642 - mape: 12.7673 - val_loss: 0.0232 - val_mae: 0.0399 - val_mape: 8.3504
# Epoch 1967/2000
# 26/26 [==============================] - 3s 109ms/step - loss: 0.0151 - mae: 0.0604 - mape: 11.7250 - val_loss: 0.0242 - val_mae: 0.0388 - val_mape: 8.7390
# Epoch 1968/2000
# 26/26 [==============================] - 3s 108ms/step - loss: 0.0141 - mae: 0.0615 - mape: 12.3089 - val_loss: 0.0248 - val_mae: 0.0447 - val_mape: 9.4966
# Epoch 1969/2000
# 26/26 [==============================] - 2s 88ms/step - loss: 0.0164 - mae: 0.0661 - mape: 13.1306 - val_loss: 0.0289 - val_mae: 0.0523 - val_mape: 11.7328
# Epoch 1970/2000
# 26/26 [==============================] - 3s 102ms/step - loss: 0.0138 - mae: 0.0632 - mape: 12.3348 - val_loss: 0.0249 - val_mae: 0.0441 - val_mape: 9.6645
# Epoch 1971/2000
# 26/26 [==============================] - 3s 103ms/step - loss: 0.0198 - mae: 0.0673 - mape: 13.4108 - val_loss: 0.0230 - val_mae: 0.0413 - val_mape: 8.5572
# Epoch 1972/2000
# 26/26 [==============================] - 3s 110ms/step - loss: 0.0149 - mae: 0.0622 - mape: 12.3259 - val_loss: 0.0251 - val_mae: 0.0452 - val_mape: 9.4635
# Epoch 1973/2000
# 26/26 [==============================] - 3s 105ms/step - loss: 0.0178 - mae: 0.0667 - mape: 12.4864 - val_loss: 0.0269 - val_mae: 0.0426 - val_mape: 8.5349
# Epoch 1974/2000
# 26/26 [==============================] - 3s 102ms/step - loss: 0.0132 - mae: 0.0609 - mape: 12.2735 - val_loss: 0.0273 - val_mae: 0.0465 - val_mape: 10.2317
# Epoch 1975/2000
# 26/26 [==============================] - 3s 111ms/step - loss: 0.0134 - mae: 0.0642 - mape: 13.0192 - val_loss: 0.0256 - val_mae: 0.0463 - val_mape: 9.6953
# Epoch 1976/2000
# 26/26 [==============================] - 2s 94ms/step - loss: 0.0138 - mae: 0.0615 - mape: 12.1241 - val_loss: 0.0257 - val_mae: 0.0392 - val_mape: 8.0738
# Epoch 1977/2000
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0166 - mae: 0.0638 - mape: 13.7899 - val_loss: 0.0252 - val_mae: 0.0447 - val_mape: 10.1230
# Epoch 1978/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0155 - mae: 0.0639 - mape: 12.2746 - val_loss: 0.0222 - val_mae: 0.0386 - val_mape: 8.4480
# Epoch 1979/2000
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0236 - mae: 0.0673 - mape: 13.2209 - val_loss: 0.0303 - val_mae: 0.0522 - val_mape: 11.2986
# Epoch 1980/2000
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0157 - mae: 0.0655 - mape: 12.6571 - val_loss: 0.0281 - val_mae: 0.0415 - val_mape: 8.8687
# Epoch 1981/2000
# 26/26 [==============================] - 3s 102ms/step - loss: 0.0154 - mae: 0.0634 - mape: 12.5637 - val_loss: 0.0242 - val_mae: 0.0381 - val_mape: 7.7648
# Epoch 1982/2000
# 26/26 [==============================] - 3s 105ms/step - loss: 0.0135 - mae: 0.0649 - mape: 13.0595 - val_loss: 0.0225 - val_mae: 0.0386 - val_mape: 7.8968
# Epoch 1983/2000
# 26/26 [==============================] - 3s 109ms/step - loss: 0.0226 - mae: 0.0728 - mape: 14.4184 - val_loss: 0.0250 - val_mae: 0.0512 - val_mape: 13.0147
# Epoch 1984/2000
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0149 - mae: 0.0634 - mape: 12.2034 - val_loss: 0.0260 - val_mae: 0.0422 - val_mape: 8.7309
# Epoch 1985/2000
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0156 - mae: 0.0663 - mape: 13.0911 - val_loss: 0.0263 - val_mae: 0.0407 - val_mape: 8.8890
# Epoch 1986/2000
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0194 - mae: 0.0645 - mape: 12.4167 - val_loss: 0.0301 - val_mae: 0.0447 - val_mape: 9.5215
# Epoch 1987/2000
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0132 - mae: 0.0602 - mape: 12.0619 - val_loss: 0.0317 - val_mae: 0.0669 - val_mape: 17.5568
# Epoch 1988/2000
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0177 - mae: 0.0678 - mape: 13.7715 - val_loss: 0.0305 - val_mae: 0.0644 - val_mape: 16.0288
# Epoch 1989/2000
# 26/26 [==============================] - 3s 100ms/step - loss: 0.0142 - mae: 0.0629 - mape: 13.3693 - val_loss: 0.0305 - val_mae: 0.0433 - val_mape: 9.5637
# Epoch 1990/2000
# 26/26 [==============================] - 3s 103ms/step - loss: 0.0149 - mae: 0.0603 - mape: 11.0013 - val_loss: 0.0348 - val_mae: 0.0469 - val_mape: 9.8569
# Epoch 1991/2000
# 26/26 [==============================] - 3s 115ms/step - loss: 0.0147 - mae: 0.0667 - mape: 13.0044 - val_loss: 0.0335 - val_mae: 0.0470 - val_mape: 10.3966
# Epoch 1992/2000
# 26/26 [==============================] - 2s 95ms/step - loss: 0.0132 - mae: 0.0609 - mape: 11.7019 - val_loss: 0.0299 - val_mae: 0.0421 - val_mape: 9.0992
# Epoch 1993/2000
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0141 - mae: 0.0634 - mape: 12.3358 - val_loss: 0.0301 - val_mae: 0.0417 - val_mape: 9.4107
# Epoch 1994/2000
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0172 - mae: 0.0634 - mape: 12.9895 - val_loss: 0.0259 - val_mae: 0.0418 - val_mape: 9.3789
# Epoch 1995/2000
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0123 - mae: 0.0616 - mape: 12.2001 - val_loss: 0.0299 - val_mae: 0.0442 - val_mape: 10.4651
# Epoch 1996/2000
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0188 - mae: 0.0651 - mape: 14.6927 - val_loss: 0.0275 - val_mae: 0.0484 - val_mape: 11.7060
# Epoch 1997/2000
# 26/26 [==============================] - 3s 101ms/step - loss: 0.0163 - mae: 0.0683 - mape: 13.6217 - val_loss: 0.0294 - val_mae: 0.0595 - val_mape: 15.3009
# Epoch 1998/2000
# 26/26 [==============================] - 3s 109ms/step - loss: 0.0133 - mae: 0.0629 - mape: 13.0577 - val_loss: 0.0324 - val_mae: 0.0457 - val_mape: 10.2813
# Epoch 1999/2000
# 26/26 [==============================] - 3s 107ms/step - loss: 0.0132 - mae: 0.0612 - mape: 12.0545 - val_loss: 0.0296 - val_mae: 0.0432 - val_mape: 9.7718
# Epoch 2000/2000
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0148 - mae: 0.0621 - mape: 12.1116 - val_loss: 0.0301 - val_mae: 0.0462 - val_mape: 10.7815

# %%
model_transform.save('transformer_medium_final.h5')

# %%
def mape(y_true, y_pred):
  mape=np.mean(np.abs((y_true - y_pred)/y_true ))*100
  # return mean of percentage errors
  return mape


def mae(y_true, y_pred):
  mae=np.mean(np.abs(y_true - y_pred))
  # return mean of percentage errors
  return mae

y=model_transform.predict([X_feature_test,X_test, X_test,y_d_test])

#_pred=sc_y.inverse_transform(y)

mape=mape(Y_test,y)
mae=mae(Y_test,y)

print('MAPE=', mape)
print('MAE=', mae)
# Out:
# 6/6 [==============================] - 1s 18ms/step
# MAPE= 7.8539844580956935
# MAE= 0.03535663335946456

# %%
# plot the loss and mape for train and validation sets
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mape'], label='train')
plt.plot(history.history['val_mape'], label='validation')
plt.title('MAPE')
plt.xlabel('Epoch')
plt.ylabel('Percentage')
plt.legend()

plt.show()

# %%
# plot and save your model
import tensorflow as tf
model_transform.summary()
img_file = 'model_transform.png'
tf.keras.utils.plot_model(model_transform, to_file=img_file, show_shapes=True, show_layer_names=True)
img_file = 'model_decode.png'
tf.keras.utils.plot_model(model_decoding, to_file=img_file, show_shapes=True, show_layer_names=True)
# Out:
# Model: "Transformer"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  LSTM_input (InputLayer)     [(None, 28, 4)]              0         []
#
#  CNN_input (InputLayer)      [(None, 28, 4)]              0         []
#
#  layer_normalization_10 (La  (None, 28, 4)                8         ['LSTM_input[0][0]']
#  yerNormalization)
#
#  position_embedding_4 (Posi  (None, 28, 4)                112       ['CNN_input[0][0]']
#  tionEmbedding)
#
#  multi_head_attention_5 (Mu  (None, 28, 4)                4564      ['layer_normalization_10[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_10[0][0]
#                                                                     ']
#
#  layer_normalization_8 (Lay  (None, 28, 4)                8         ['position_embedding_4[0][0]']
#  erNormalization)
#
#  dropout_12 (Dropout)        (None, 28, 4)                0         ['multi_head_attention_5[0][0]
#                                                                     ']
#
#  multi_head_attention_4 (Mu  (None, 28, 4)                4564      ['layer_normalization_8[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_8[0][0]
#                                                                     ']
#
#  tf.__operators__.add_10 (T  (None, 28, 4)                0         ['dropout_12[0][0]',
#  FOpLambda)                                                          'LSTM_input[0][0]']
#
#  dropout_10 (Dropout)        (None, 28, 4)                0         ['multi_head_attention_4[0][0]
#                                                                     ']
#
#  layer_normalization_11 (La  (None, 28, 4)                8         ['tf.__operators__.add_10[0][0
#  yerNormalization)                                                  ]']
#
#  tf.__operators__.add_8 (TF  (None, 28, 4)                0         ['dropout_10[0][0]',
#  OpLambda)                                                           'position_embedding_4[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 28, 2)                10        ['layer_normalization_11[0][0]
#                                                                     ']
#
#  layer_normalization_9 (Lay  (None, 28, 4)                8         ['tf.__operators__.add_8[0][0]
#  erNormalization)                                                   ']
#
#  dropout_13 (Dropout)        (None, 28, 2)                0         ['conv1d_10[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 28, 2)                10        ['layer_normalization_9[0][0]'
#                                                                     ]
#
#  conv1d_11 (Conv1D)          (None, 28, 4)                12        ['dropout_13[0][0]']
#
#  dropout_11 (Dropout)        (None, 28, 2)                0         ['conv1d_8[0][0]']
#
#  tf.__operators__.add_11 (T  (None, 28, 4)                0         ['conv1d_11[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  conv1d_9 (Conv1D)           (None, 28, 4)                12        ['dropout_11[0][0]']
#
#  lstm_4 (LSTM)               (None, 28, 200)              164000    ['tf.__operators__.add_11[0][0
#                                                                     ]']
#
#  tf.__operators__.add_9 (TF  (None, 28, 4)                0         ['conv1d_9[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_8[0][0]
#                                                                     ']
#
#  flatten_5 (Flatten)         (None, 5600)                 0         ['lstm_4[0][0]']
#
#  flatten_4 (Flatten)         (None, 112)                  0         ['tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  dense_26 (Dense)            (None, 50)                   280050    ['flatten_5[0][0]']
#
#  dense_24 (Dense)            (None, 50)                   5650      ['flatten_4[0][0]']
#
#  concatenate_2 (Concatenate  (None, 100)                  0         ['dense_26[0][0]',
#  )                                                                   'dense_24[0][0]']
#
#  dense_27 (Dense)            (None, 200)                  20200     ['concatenate_2[0][0]']
#
#  dense_28 (Dense)            (None, 16)                   3216      ['dense_27[0][0]']
#
#  feature (InputLayer)        [(None, 3)]                  0         []
#
#  lag_input (InputLayer)      [(None, None, 1)]            0         []
#
#  decoding_model (Functional  (None, 1)                    5703      ['dense_28[0][0]',
#  )                                                                   'feature[0][0]',
#                                                                      'lag_input[0][0]']
#
# ==================================================================================================
# Total params: 488135 (1.86 MB)
# Trainable params: 488135 (1.86 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
#validation
x_predictn=np.zeros((1,28))
#x_predictn[0,:]=[10,18,18,20,25,18,20,18,5,2,10,9,10,5,8,6,6,4,7,12,23,24,25,25,54,27,23]
x_predictn[0,:]=data[15,1:29]
X_predict = sc.transform(x_predictn)
x_feature=np.zeros((1,3))
x_feature[0,0]=100 #blow
x_feature[0,1]=2 #fine
x_feature[0,2]=3 #thickness
X_feature = sc_f.transform(x_feature)

x_cal=np.zeros((1,time_step,4))
x_cal[:,:,0]=X_predict
x_cal[:,:,1]=X_feature[0,0]
x_cal[:,:,2]=X_feature[0,1]
x_cal[:,:,3]=X_feature[0,2]
#y=model_transform.predict([X_feature,x_cal,x_cal])
#y=sc_y.inverse_transform(y)
print(y)
#plot
#set initial
y_d=np.array([0])
y_dp=np.pad(y_d,(0,27-1),mode='constant')
ydp=np.reshape(ydp,(1,1,1))
y_predict=np.array([])
for step in range(1,28):

  y=model_transform.predict([X_feature,x_cal, x_cal,ydp])
  y_predict=np.append(y_predict,y,axis=1)
  y_predict_pad=np.pad(y_predict,(0,27-y_predict.shape[0]),mode='constant')
  ydp=np.reshape(y_predict,(1,y_predict_pad.shape[0],1))

y=sc_y.inverse_transform(y_predict)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# [[12.665335  20.222157  17.452772  17.656559   8.589509  16.672186
#   13.6676    17.749722  10.339917   6.512298   2.4884915  9.596858
#   10.590686   9.950588   5.000565   0.8689195  2.5275192  2.0243032
#    1.7829946  3.0317461  5.111828   4.523933   2.301327   2.3277225
#    3.2947867  3.813728   3.302409   4.1380854]]

# %%
import matplotlib.pyplot as plt

# Define the x-axis and corresponding y-axis values as lists

ydist=[0.25,0.5,0.75,1,1.25,1.5,1.75,2,2.25,2.5,2.75,3,3.25,3.5,3.75,4,4.25,4.5,4.75,5,5.25,5.5,5.75,6,6.25,6.5,6.75,7]


# Plot them on canvas using plt.plot() function
plt.plot(y[0,:], ydist,color='red',label='predict')
plt.plot(x_predictn[0,:], ydist,color='blue',label='initial')
plt.legend()


# Give a name to x-axis and y-axis using plt.xlabel() and plt.ylabel() functions
plt.xlabel("Qc")
plt.ylabel("depth")

# Give a title to your plot using plt.title() function
plt.title("Qc VS depth")
# Get the current axes instance
ax = plt.gca()

# Invert the y-axis
ax.invert_yaxis()

# Finally, to view your plot, we use plt.show() function
plt.show()

# %%
model_transform.save('transformer.h5')

# %%
#Model generation part
#import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Dense, Conv1D, Flatten, concatenate,Reshape, Dropout,Bidirectional,LayerNormalization
from keras.layers import MaxPooling1D
from keras.layers import LSTM, Dense
from keras.metrics import MeanAbsolutePercentageError
from keras import *
from keras.optimizers import Adam
import keras_nlp
model_transform = models.load_model('/content/drive/MyDrive/RIC/train_model/model1/transformer_medium_final.h5')
def mape(y_true, y_pred):
  mape=np.mean(np.abs((y_true - y_pred)/y_true ))*100
  # return mean of percentage errors
  return mape


def mae(y_true, y_pred):
  mae=np.mean(np.abs(y_true - y_pred))
  # return mean of percentage errors
  return mae

y=model_transform.predict([x_f,x_train_encoder, x_train_encoder,y_decode])

#_pred=sc_y.inverse_transform(y)

mape=mape(y_train,y)
mae=mae(y_train,y)

print('MAPE=', mape)
print('MAE=', mae)
# Out:
# 30/30 [==============================] - 5s 44ms/step
# MAPE= 7.1796924685346415
# MAE= 0.03377492039120414

# %%
x_f=encoder_f(x_feature,28)
x_train_encoder=encoder_x(X_train_CNN)
y_decode=padding_full(x_pad=y_train, shift=1)
y_decode = np.delete (y_decode, -1, axis=1)
y_train=out_put(y_train)

# %%
import matplotlib.pyplot as plt


Y=data[:,34:62]

y_train=sc_y.inverse_transform(y_train)
# Plot the data points as a scatter plot
plt.scatter(y, y_train, s=1)

# Add labels and title
plt.xlabel('cone resistance (MPa)')
plt.ylabel('predicted cone resistance (MPa)')


# Show the plot on the screen
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-063c2449e63e> in <cell line: 6>()
#       4 Y=data[:,34:62]
#       5
# ----> 6 y_train=sc_y.inverse_transform(y_train)
#       7 # Plot the data points as a scatter plot
#       8 plt.scatter(y, y_train, s=1)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X, copy)
#    1050         else:
#    1051             if self.with_std:
# -> 1052                 X *= self.scale_
#    1053             if self.with_mean:
#    1054                 X += self.mean_
#
# ValueError: non-broadcastable output operand with shape (952,1) doesn't match the broadcast shape (952,28)

# %%
com=np.concatenate((y_pred,Y),axis=0)
np.savetxt('predict.csv', com, delimiter=',')

# %%
Y_sp=y_pred.T
Y_ST=Y.T
for i in range(0,27):
  Y_p=Y_P

# %%
Y_ST.shape
# Out:
# (28, 26)

# %%
#Transformer Autoencoder to predict RIC combind model by Dr. Sompote Youwai 2023
import numpy as np
import pandas as pd

# Import libraries
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import pandas as pd



df2 = pd.read_excel('/content/drive/MyDrive/RIC/RIC7aug.xlsx')
data=np.array(df2)
X=data[-2:,1:29]
Y=data[-2:,34:62]
X_feature=data[-2:,29:32]

# %%
Y.shape
# Out:
# (2, 28)

# %%
Y#scale data
X_train=X
Y_train=Y


x_train = sc.transform(X_train)
y_train=sc_y.transform(Y_train)
x_feature=sc_f.transform(X_feature)

# %%
x_feature
# Out:
# array([[-1.37685678, -2.34417712,  0.27530479],
#        [-1.37685678, -2.34417712,  0.27530479]])

# %%
X_train_CNN=np.zeros((X.shape[0],X.shape[1],x_feature.shape[1]+1))
X_train_CNN[:,:,0]=x_train
for i in range(0,(X.shape[0])):
  X_train_CNN[i,:,1]=x_feature[i,0]
  X_train_CNN[i,:,2]=x_feature[i,1]
  X_train_CNN[i,:,3]=x_feature[i,2]

# %%
X_train_CNN
# Out:
# array([[[-0.93350493, -1.37685678, -2.34417712,  0.27530479],
#         [-0.57271124, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.40178498, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.86765545, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.70489386, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.20522221, -1.37685678, -2.34417712,  0.27530479],
#         [ 1.02954651, -1.37685678, -2.34417712,  0.27530479],
#         [ 2.9617748 , -1.37685678, -2.34417712,  0.27530479],
#         [ 1.8313836 , -1.37685678, -2.34417712,  0.27530479],
#         [ 1.26810271, -1.37685678, -2.34417712,  0.27530479],
#         [ 1.1669807 , -1.37685678, -2.34417712,  0.27530479],
#         [ 3.94904658, -1.37685678, -2.34417712,  0.27530479],
#         [ 3.77389936, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.87160822, -1.37685678, -2.34417712,  0.27530479],
#         [-0.36501563, -1.37685678, -2.34417712,  0.27530479],
#         [-0.57764094, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.92135235, -1.37685678, -2.34417712,  0.27530479],
#         [ 1.6837671 , -1.37685678, -2.34417712,  0.27530479],
#         [ 1.11366626, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.23380518, -1.37685678, -2.34417712,  0.27530479],
#         [-0.1645746 , -1.37685678, -2.34417712,  0.27530479],
#         [-0.21766463, -1.37685678, -2.34417712,  0.27530479],
#         [-0.02634909, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.2335371 , -1.37685678, -2.34417712,  0.27530479],
#         [ 0.93369929, -1.37685678, -2.34417712,  0.27530479],
#         [ 1.33701907, -1.37685678, -2.34417712,  0.27530479],
#         [-0.45797974, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.80198002, -1.37685678, -2.34417712,  0.27530479]],
#
#        [[-0.81753728, -1.37685678, -2.34417712,  0.27530479],
#         [-0.66841316, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.47046422, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.79765122, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.86249265, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.29909715, -1.37685678, -2.34417712,  0.27530479],
#         [-0.22551388, -1.37685678, -2.34417712,  0.27530479],
#         [-0.57049639, -1.37685678, -2.34417712,  0.27530479],
#         [-0.52292769, -1.37685678, -2.34417712,  0.27530479],
#         [ 1.16951515, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.72338465, -1.37685678, -2.34417712,  0.27530479],
#         [ 2.86596676, -1.37685678, -2.34417712,  0.27530479],
#         [ 2.48083287, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.66438416, -1.37685678, -2.34417712,  0.27530479],
#         [ 1.10184171, -1.37685678, -2.34417712,  0.27530479],
#         [ 2.12956474, -1.37685678, -2.34417712,  0.27530479],
#         [ 2.13621784, -1.37685678, -2.34417712,  0.27530479],
#         [ 2.12347881, -1.37685678, -2.34417712,  0.27530479],
#         [ 1.04294959, -1.37685678, -2.34417712,  0.27530479],
#         [ 0.01877475, -1.37685678, -2.34417712,  0.27530479],
#         [-0.41647517, -1.37685678, -2.34417712,  0.27530479],
#         [-0.55283747, -1.37685678, -2.34417712,  0.27530479],
#         [-0.46549021, -1.37685678, -2.34417712,  0.27530479],
#         [-0.91592473, -1.37685678, -2.34417712,  0.27530479],
#         [-1.8247137 , -1.37685678, -2.34417712,  0.27530479],
#         [-1.89846193, -1.37685678, -2.34417712,  0.27530479],
#         [-1.17017456, -1.37685678, -2.34417712,  0.27530479],
#         [-1.09583401, -1.37685678, -2.34417712,  0.27530479]]])

# %%
y=model_transform.predict([x_feature,X_train_CNN,X_train_CNN])
y_pred=sc_y.inverse_transform(y)
# Out:
# 1/1 [==============================] - 0s 32ms/step

# %%
np.savetxt('array2.csv', y_pred, delimiter=',')

# %%
import matplotlib.pyplot as plt


Y=data[-2:,34:62]

# Plot the data points as a scatter plot
plt.scatter(Y, y_pred, s=3)

# Add labels and title
plt.xlabel('cone resistance (MPa)')
plt.ylabel('predicted cone resistance (MPa)')


# Show the plot on the screen
plt.show()

# %%
import pickle
pickle.dump(sc, open('scaler_x.pkl', 'wb'))
pickle.dump(sc_y, open('scaler_y.pkl', 'wb'))
pickle.dump(sc_f, open('scaler_f.pkl', 'wb'))
